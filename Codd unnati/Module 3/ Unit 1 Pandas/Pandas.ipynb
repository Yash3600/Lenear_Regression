# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Titanic Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df = pd.read_csv('Titanic Dataset.csv')
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv('Titanic Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(['Cabin'],axis =1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(['Cabin'],axis =1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 df.drop(['Cabin'],axis =1,inplace = True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
df = pd.read_csv('Titanic Dataset.csv')

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Embarked
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.fillna(np.mean)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# ...

# %%
df.fillna(np.mean).isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.fillna(np.mean).isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
dir(df)
# Out:
# ['Age',
#  'Embarked',
#  'Fare',
#  'Name',
#  'Parch',
#  'PassengerId',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'T',
#  'Ticket',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
# ...

# %%
df['Survived'].value_counts().plot(kind = "bar");

# %%
df['Sex'].value_counts().plot(kind = "bar");

# %%
df['Survived'].value_counts().plot(kind = "pie");

# %%
import seaborn as sns

# %%
sns.barplot(data = df,x = df["Survived"],y = df['Survived'].value_counts(),hue = df['Sex'])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Survived'>

# %%
sns.barplot(data = df,x = df["Survived"],y = df['Survived'].value_counts(),hue = df['Sex']);

# %%
sns.displot(data = xf,df["Sex"])
# Out:
#   Input In [27]
#     sns.displot(data = df,df["Sex"])
#                                    ^
# SyntaxError: positional argument follows keyword argument

# %%
sns.displot(data = df,x = df["Sex"]);

# %%
sns.displot(data = df,x = df["Age"]);

# %%
sns.displot(data = df,x = df["Age"],hue = df['Sex']);

# %%
sns.displot(data = df,x = df["Age"],hue = df['Pclass']);

# %%
df.var()
# Out:
# C:\Users\SAP\AppData\Local\Temp\ipykernel_14328\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# PassengerId    66231.000000
# Survived           0.236772
# Pclass             0.699015
# Age              211.019125
# SibSp              1.216043
# Parch              0.649728
# Fare            2469.436846
# dtype: float64

# %%
sns.heatmap(df.corr());

# %%
sns.heatmap(df.corr(),annot=True);

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.scatterplot(data = df, x = "Survived", y = "Pclass");

# %%
df[["Age"]].replace(22,"A")
# Out:
#       Age
# 0       A
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
def sort_age(col):
    if col <18:
        col.replace("Child")
    return col

# %%
sort_age(df["Age"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 sort_age(df["Age"])
#
# Input In [10], in sort_age(col)
#       1 def sort_age(col):
# ----> 2     if col <18:
#       3         col.replace("Child")
#       4     return col
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df["Age"]<18
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
(df["Age"]<18).sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool>

# %%
df[df["Age"]<18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df["Age_updated"] = v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 df["Age_updated"] = v
#
# NameError: name 'v' is not defined

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.scatterplot(data = df, x = "Survived", y = "Age");

# %%
sns.scatterplot(data = df, x = "Survived", y = "Age", hue = "Sex");

# %%
sns.scatterplot(data = df, x = "Age", y = "Survived");

# %%
sns.scatterplot(data = df, x = "Survived", y = "Name");

# %%
df = pd.read_csv('Titanic Dataset.csv')

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.fillna(np.mean)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.dropna

# %%
df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 df.isna().sum()
#
# AttributeError: 'function' object has no attribute 'isna'

# %%
df = pd.read_csv('Titanic Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df = pd.read_csv('Titanic Dataset.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d = df.groupby(df["Survived"])['Sex'].count()

# %%
d
# Out:
# Survived
# 0    549
# 1    342
# Name: Sex, dtype: int64

# %%
d.plot(kind= 'bar')
# Out:
# <AxesSubplot:xlabel='Survived'>

# %%
df.plot(kind = "bar");

# %%
a = df.pivot_table(values='PassengerId', index="Survived",columns="Sex",aggfunc="count")
a
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
a.plot(kind = "bar");

# %%
a.plot(kind = "box");

# %%
e = df.groupby(by=["Survived","Sex"])["Age"].count()

# %%
e
# Out:
# Survived  Sex
# 0         female     64
#           male      360
# 1         female    197
#           male       93
# Name: Age, dtype: int64

# %%
e.plot(kind = "bar");

# %%
e.plot(kind = "bar",color = ['r','b','y','g']);

# %%
b = df.pivot_table(values='PassengerId', index="Pclass",columns="Sex",aggfunc="count")

# %%
b.plot(kind = "bar");

# %%
c = df.pivot_table(values='PassengerId', index="Survived",columns="Embarked",aggfunc="count")

# %%
c.plot(kind = "bar");

# %%
import pandas as pd

# %%
a={"ID":[1,2,3,4],"Name":["yug","moksh","chintan","khushi"],
"City":["dharti","swarge","pruthvi","pacific"]}
df3 = pd.DataFrame(a)

# %%
df3
# Out:
#    ID     Name     City
# 0   1      yug   dharti
# 1   2    moksh   swarge
# 2   3  chintan  pruthvi
# 3   4   khushi  pacific

# %%
df3["Age"] = [19,20,23,18]

# %%
df3
# Out:
#    ID     Name     City  Age
# 0   1      yug   dharti   19
# 1   2    moksh   swarge   20
# 2   3  chintan  pruthvi   23
# 3   4   khushi  pacific   18

# %%
f={"ID":[1,2,3,4,5],
   "Name":["yug","moksh","chintan","khushi",'yash'],
"City":["dharti","swarge","pruthvi","pacific",'tirupati'],
   "Weight":[50,56,33,24,24],
   "Age":["19","20","18","21","22"]}
df2= pd.DataFrame(f)

# %%
df2
# Out:
#    ID     Name      City  Weight Age
# 0   1      yug    dharti      50  19
# 1   2    moksh    swarge      56  20
# 2   3  chintan   pruthvi      33  18
# 3   4   khushi   pacific      24  21
# 4   5     yash  tirupati      24  22

# %%
g={"ID":[1,2,3,4,5],"Weight":["50","59","70","60","72"],}
df1 = pd.DataFrame(g)
df1
# Out:
#    ID Weight
# 0   1     50
# 1   2     59
# 2   3     70
# 3   4     60
# 4   5     72

# %%
pd.concat([df3,df1])
# Out:
#    ID     Name     City   Age Weight
# 0   1      yug   dharti  19.0    NaN
# 1   2    moksh   swarge  20.0    NaN
# 2   3  chintan  pruthvi  23.0    NaN
# 3   4   khushi  pacific  18.0    NaN
# 0   1      NaN      NaN   NaN     50
# 1   2      NaN      NaN   NaN     59
# 2   3      NaN      NaN   NaN     70
# 3   4      NaN      NaN   NaN     60
# 4   5      NaN      NaN   NaN     72

# %%
pd.concat([df2,df1])
# Out:
#    ID     Name      City Weight  Age
# 0   1      yug    dharti     50   19
# 1   2    moksh    swarge     56   20
# 2   3  chintan   pruthvi     33   18
# 3   4   khushi   pacific     24   21
# 4   5     yash  tirupati     24   22
# 0   1      NaN       NaN     50  NaN
# 1   2      NaN       NaN     59  NaN
# 2   3      NaN       NaN     70  NaN
# 3   4      NaN       NaN     60  NaN
# 4   5      NaN       NaN     72  NaN

# %%
df3.merge(df1)
# Out:
#    ID     Name     City  Age Weight
# 0   1      yug   dharti   19     50
# 1   2    moksh   swarge   20     59
# 2   3  chintan  pruthvi   23     70
# 3   4   khushi  pacific   18     60

# %%
df2.merge(df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 df2.merge(df1)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
#    9354         sort=sort,
#    9355         suffixes=suffixes,
# ...

# %%
df3.merge(df1,how = "outer")
# Out:
#    ID     Name     City   Age Weight
# 0   1      yug   dharti  19.0     50
# 1   2    moksh   swarge  20.0     59
# 2   3  chintan  pruthvi  23.0     70
# 3   4   khushi  pacific  18.0     60
# 4   5      NaN      NaN   NaN     72

# %%
df2.merge(df1,how = "outer")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 df2.merge(df1,how = "outer")
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
#    9354         sort=sort,
# ...

# %%
df3.merge(df1,how = "left")
# Out:
#    ID     Name     City  Age Weight
# 0   1      yug   dharti   19     50
# 1   2    moksh   swarge   20     59
# 2   3  chintan  pruthvi   23     70
# 3   4   khushi  pacific   18     60

# %%
df3.merge(df1,how = "right")
# Out:
#    ID     Name     City   Age Weight
# 0   1      yug   dharti  19.0     50
# 1   2    moksh   swarge  20.0     59
# 2   3  chintan  pruthvi  23.0     70
# 3   4   khushi  pacific  18.0     60
# 4   5      NaN      NaN   NaN     72

# %%
df3.merge(df1,how = "inner")
# Out:
#    ID     Name     City  Age Weight
# 0   1      yug   dharti   19     50
# 1   2    moksh   swarge   20     59
# 2   3  chintan  pruthvi   23     70
# 3   4   khushi  pacific   18     60

# %%
df3.merge(df1,how = "left").reset_index()
# Out:
#    index  ID     Name     City  Age Weight
# 0      0   1      yug   dharti   19     50
# 1      1   2    moksh   swarge   20     59
# 2      2   3  chintan  pruthvi   23     70
# 3      3   4   khushi  pacific   18     60

# %%
df3.merge(df1,how = "left").sort_index()
# Out:
#    ID     Name     City  Age Weight
# 0   1      yug   dharti   19     50
# 1   2    moksh   swarge   20     59
# 2   3  chintan  pruthvi   23     70
# 3   4   khushi  pacific   18     60

# %%
df3.merge(df1,how = "left").sort_index(ignore_index = True)
# Out:
#    ID     Name     City  Age Weight
# 0   1      yug   dharti   19     50
# 1   2    moksh   swarge   20     59
# 2   3  chintan  pruthvi   23     70
# 3   4   khushi  pacific   18     60

# %%
df3.merge(df1,how = "left").sort_index(ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df3.merge(df1,how = "left").sort_index(ignore_index = True)
#
# NameError: name 'df3' is not defined

# %%
df3.sort_values('Name')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df3.sort_values('Name')
#
# NameError: name 'df3' is not defined

# %%
df3.sort_values('Age')
# Out:
#    ID     Name     City  Age
# 3   4   khushi  pacific   18
# 0   1      yug   dharti   19
# 1   2    moksh   swarge   20
# 2   3  chintan  pruthvi   23

# %%
a = lambda x:x**2

# %%
a(4)
# Out:
# 16

# %%
b = lambda x:x**0.5

# %%
b(16)
# Out:
# 4.0

# %%
df3['Age'].apply(lambda x:x**2)
# Out:
# 0    361
# 1    400
# 2    529
# 3    324
# Name: Age, dtype: int64

# %%
df2['Weight'].apply(lambda x:x**2)
# Out:
# 0    2500
# 1    3136
# 2    1089
# 3     576
# 4     576
# Name: Weight, dtype: int64

# %%
new = df3.loc[:50]

# %%
new
# Out:
#    ID     Name     City  Age
# 0   1      yug   dharti   19
# 1   2    moksh   swarge   20
# 2   3  chintan  pruthvi   23
# 3   4   khushi  pacific   18

# %%
df3[""].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fase'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
